# %%
import pandas as pd
    
import numpy as np

# %%
df = pd.read_excel(r"E:\Data Science\data set\global_superstore_2016.xlsx")

df.head(2)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  ...  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City  ...
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong  ...
#
#     Product ID    Category Sub-Category  \
# 0  TEC-PH-5816  Technology       Phones
# 1  FUR-CH-5379   Furniture       Chairs
#
#                                 Product Name     Sales Quantity Discount  \
# 0                           Samsung Convoy 3   221.980        2      0.0
# 1  Novimex Executive Leather Armchair, Black  3709.395        9      0.1
#
#      Profit  Shipping Cost  Order Priority
# 0   62.1544          40.77            High
# 1 -288.7650         923.63        Critical
#
# [2 rows x 24 columns]

# %% [markdown]
# # Transpose

# %%
df.head().T
# Out:
#                                        0  \
# Row ID                             40098
# Order ID        CA-2014-AB10015140-41954
# Order Date           2014-11-11 00:00:00
# Ship Date            2014-11-13 00:00:00
# Ship Mode                    First Class
# Customer ID                 AB-100151402
# Customer Name              Aaron Bergman
# Segment                         Consumer
# Postal Code                      73120.0
# City                       Oklahoma City
# State                           Oklahoma
# Country                    United States
# Region                        Central US
# Market                              USCA
# Product ID                   TEC-PH-5816
# Category                      Technology
# Sub-Category                      Phones
# Product Name            Samsung Convoy 3
# Sales                             221.98
# Quantity                               2
# Discount                             0.0
# Profit                           62.1544
# ...

# %%
df.tail()


# this gives last 5 rows from the dataframe/file
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                 City  ...   Product ID         Category Sub-Category  \
# ...

# %%
df.tail(2)
# Out:
#        Row ID                 Order ID Order Date  Ship Date       Ship Mode  \
# 51288    9596  MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147  MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#       Customer ID  Customer Name      Segment  Postal Code      City  ...  \
# 51288  RB-1979518     Ross Baird  Home Office          NaN  Valinhos  ...
# 51289  MC-1810093  Mick Crebagga     Consumer          NaN  Tipitapa  ...
#
#         Product ID         Category Sub-Category  \
# 51288  OFF-BI-2919  Office Supplies      Binders
# 51289  OFF-PA-3990  Office Supplies        Paper
#
#                                   Product Name  Sales Quantity Discount  \
# 51288                  Acco Index Tab, Economy  13.44        2      0.0
# 51289  Eaton Computer Printout Paper, 8.5 x 11  61.38        3      0.0
#
#       Profit  Shipping Cost  Order Priority
# 51288    2.4          1.003          Medium
# 51289    1.8          1.002            High
#
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
# we called it as metadata

# this gives basic information of the data like- how much memory file takes in python to store this table, no. of rows & columns, data type


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  object
#  10  State           51290 non-null  object
#  11  Country         51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Market          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
# This gives basic aggreation about the only numerical columns,it do not considered the text column

# 25%,50%,75% is not percentage, it is percentile 


df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.478567
# std      174.340972      57.251373
# min    -6599.978000       1.002000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
# Null values also denoted as NaN, None & NaT

# %%
# I want to know all names of columns present in the table


df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# If I want to know all Index present in the table



df.index


# it tells, starts with 0 and end at 51290, step = 1 means indexing is going one by one like 0,1,2,3,4.....51288,51289,51290
# Out:
# RangeIndex(start=0, stop=51290, step=1)

# %%
# Now, I want to datatypes of each column 


df.dtypes                                          # object means character/string
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
# It tell unique values present in the columns


df.nunique()
# Out:
# Row ID            51290
# Order ID          25728
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID       17415
# Customer Name       796
# Segment               3
# Postal Code         631
# City               3650
# State              1102
# Country             165
# Region               23
# Market                5
# Product ID         3788
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             27200
# Quantity             14
# Discount             29
# Profit            28234
# Shipping Cost     16753
# Order Priority        4
# dtype: int64

# %%
# If I want to know what unique values present in the column "Segment"


df['Segment'].nunique()
# Out:
# 3

# %%
df['Segment'].value_counts()
# Out:
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: Segment, dtype: int64

# %%
df.head(2)
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  ...  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City  ...
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong  ...
#
#     Product ID    Category Sub-Category  \
# 0  TEC-PH-5816  Technology       Phones
# 1  FUR-CH-5379   Furniture       Chairs
#
#                                 Product Name     Sales Quantity Discount  \
# 0                           Samsung Convoy 3   221.980        2      0.0
# 1  Novimex Executive Leather Armchair, Black  3709.395        9      0.1
#
#      Profit  Shipping Cost  Order Priority
# 0   62.1544          40.77            High
# 1 -288.7650         923.63        Critical
#
# [2 rows x 24 columns]

# %%
# so, from above we know home office as 9343 rows, i want to access all these rows



df['Segment'] == "Home Office"
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288     True
# 51289    False
# Name: Segment, Length: 51290, dtype: bool

# %%
# it gives answer in boolean values 


# So, I want to access all rows of home office with the all other informations/columns


df[df["Segment"] == "Home Office"]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 13       4132   MX-2013-VF2171518-41591 2013-11-13 2013-11-13        Same Day
# 23      13528  ES-2014-LB16795139-41697 2014-02-27 2014-03-01    Second Class
# 41      29272   IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 68       8029   MX-2015-EM1420082-42328 2015-11-20 2015-11-20        Same Day
# ...       ...                       ...        ...        ...             ...
# 51273    9309   MX-2015-SL2015518-42258 2015-09-11 2015-09-12     First Class
# 51277   46582   TU-2015-KF6285134-42337 2015-11-29 2015-11-30     First Class
# 51282   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
#
# ...

# %%
# Now, I want to know only index of the above



df[df["Segment"] == "Home Office"].index
# Out:
# Int64Index([    3,    13,    23,    41,    68,    69,    78,    86,    92,
#                97,
#             ...
#             51205, 51212, 51220, 51231, 51266, 51273, 51277, 51282, 51284,
#             51288],
#            dtype='int64', length=9343)

# %%
# Now, I want to access particular columns instead of all information/columns 


df[df["Segment"] == "Home Office"] [["Segment", "Region", "City"]]
# Out:
#            Segment           Region           City
# 3      Home Office   Western Europe         Berlin
# 13     Home Office    South America         Toledo
# 23     Home Office  Northern Europe      Edinburgh
# 41     Home Office    Southern Asia      Gorakhpur
# 68     Home Office  Central America  Gómez Palacio
# ...            ...              ...            ...
# 51273  Home Office    South America     Vespasiano
# 51277  Home Office     Western Asia         Midyat
# 51282  Home Office          Oceania     Townsville
# 51284  Home Office  Central America        Managua
# 51288  Home Office    South America       Valinhos
#
# [9343 rows x 3 columns]

# %% [markdown]
# #### Same thing doing using loc function

# %%
# So, I want to access all rows of home office with the all other informations/columns


df.loc[df["Segment"] == "Home Office"]
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 13       4132   MX-2013-VF2171518-41591 2013-11-13 2013-11-13        Same Day
# 23      13528  ES-2014-LB16795139-41697 2014-02-27 2014-03-01    Second Class
# 41      29272   IN-2015-BF1100558-42319 2015-11-11 2015-11-15  Standard Class
# 68       8029   MX-2015-EM1420082-42328 2015-11-20 2015-11-20        Same Day
# ...       ...                       ...        ...        ...             ...
# 51273    9309   MX-2015-SL2015518-42258 2015-09-11 2015-09-12     First Class
# 51277   46582   TU-2015-KF6285134-42337 2015-11-29 2015-11-30     First Class
# 51282   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
#
# ...

# %%
df.loc[df["Segment"] == "Home Office" , "City":].head(2)
# Out:
#       City   State  Country          Region  Market   Product ID    Category  \
# 3   Berlin  Berlin  Germany  Western Europe  Europe  TEC-PH-5267  Technology
# 13  Toledo  Parana   Brazil   South America   LATAM  FUR-CH-4530   Furniture
#
#    Sub-Category                                       Product Name    Sales  \
# 3        Phones                     Motorola Smart Phone, Cordless  2892.51
# 13       Chairs  Harbour Creations Executive Leather Armchair, ...  2221.80
#
#     Quantity  Discount  Profit  Shipping Cost Order Priority
# 3          5       0.1  -96.54         910.16         Medium
# 13         7       0.0  622.02         810.25       Critical

# %% [markdown]
# #### If I want to change the data type of the any column   -  use astype

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
# Change Row ID data type from int to string



df["Row ID"] = df["Row ID"].astype("str")


df.dtypes
# Out:
# Row ID                    object
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Postal Code              float64
# City                      object
# State                     object
# Country                   object
# Region                    object
# Market                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %% [markdown]
# #### Sample

# %%
# Sample give random rows from the table, and every time we exceute it will give random rows every time



df.sample(5)       # 5 means I want random 5 rows
# Out:
#       Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 48730  36579  CA-2013-SP20860140-41522 2013-09-05 2013-09-10  Standard Class
# 574    37710  CA-2015-AH10120140-42234 2015-08-18 2015-08-24  Standard Class
# 20658  35440  CA-2015-EH14125140-42035 2015-01-31 2015-02-07  Standard Class
# 43220  38954  US-2012-PS18970140-41013 2012-04-14 2012-04-14        Same Day
# 4066   48810    EG-2013-RA928538-41488 2013-08-02 2013-08-04    Second Class
#
#         Customer ID      Customer Name      Segment  Postal Code  \
# 48730  SP-208601402           Sung Pak    Corporate      55901.0
# 574    AH-101201408        Adrian Hane  Home Office      40214.0
# 20658  EH-141251404  Eugene Hildebrand  Home Office      94110.0
# 43220  PS-189701404     Paul Stevenson  Home Office      90049.0
# 4066      RA-928538       Ralph Arnett     Consumer          NaN
#
#                 City  ...   Product ID         Category Sub-Category  \
# ...

# %%
# in this table we have 51000 approx. rows, I want 25% of rows from the table



df.sample(frac = 0.25)


# It will give random 25% of rows from the 51000 approx. rows
# Out:
#       Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 5809   26058  IN-2013-CC12670144-41593 2013-11-15 2013-11-17    Second Class
# 41820  24956   IN-2013-NW1840027-41502 2013-08-16 2013-08-23  Standard Class
# 10782  15771   ES-2012-JO1514545-41072 2012-06-12 2012-06-17  Standard Class
# 38600  35772  CA-2015-MG17680140-42277 2015-09-30 2015-09-30        Same Day
# 26306  39366  CA-2015-JM15250140-42006 2015-01-02 2015-01-06  Standard Class
# ...      ...                       ...        ...        ...             ...
# 17887   9537   MX-2015-PS1897028-42201 2015-07-16 2015-07-20  Standard Class
# 11487  50282    IZ-2015-JR567061-42241 2015-08-25 2015-08-25        Same Day
# 1776   19992  IT-2014-MF18250139-41646 2014-01-07 2014-01-14  Standard Class
# 48852  47048   TU-2014-EM3825134-41707 2014-03-09 2014-03-12    Second Class
# 39508  24803   IN-2013-NH1861059-41417 2013-05-23 2013-05-28    Second Class
#
# ...

# %% [markdown]
# # Droping the data

# %%
# It can drop rows or columns

# Does not drop the data from the orginal data/source file permanently

# %%
df.head(2)
# Out:
#   Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0  40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1  26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
#
#     Customer ID  Customer Name    Segment  Postal Code           City  ...  \
# 0  AB-100151402  Aaron Bergman   Consumer      73120.0  Oklahoma City  ...
# 1     JR-162107  Justin Ritter  Corporate          NaN     Wollongong  ...
#
#     Product ID    Category Sub-Category  \
# 0  TEC-PH-5816  Technology       Phones
# 1  FUR-CH-5379   Furniture       Chairs
#
#                                 Product Name     Sales Quantity Discount  \
# 0                           Samsung Convoy 3   221.980        2      0.0
# 1  Novimex Executive Leather Armchair, Black  3709.395        9      0.1
#
#      Profit  Shipping Cost  Order Priority
# 0   62.1544          40.77            High
# 1 -288.7650         923.63        Critical
#
# [2 rows x 24 columns]

# %%
df.drop(columns = ["Row ID","Order ID","Customer ID"]).head(2)
# Out:
#   Order Date  Ship Date     Ship Mode  Customer Name    Segment  Postal Code  \
# 0 2014-11-11 2014-11-13   First Class  Aaron Bergman   Consumer      73120.0
# 1 2014-02-05 2014-02-07  Second Class  Justin Ritter  Corporate          NaN
#
#             City            State        Country      Region  ...  \
# 0  Oklahoma City         Oklahoma  United States  Central US  ...
# 1     Wollongong  New South Wales      Australia     Oceania  ...
#
#     Product ID    Category Sub-Category  \
# 0  TEC-PH-5816  Technology       Phones
# 1  FUR-CH-5379   Furniture       Chairs
#
#                                 Product Name     Sales  Quantity  Discount  \
# 0                           Samsung Convoy 3   221.980         2       0.0
# 1  Novimex Executive Leather Armchair, Black  3709.395         9       0.1
#
#      Profit  Shipping Cost  Order Priority
# 0   62.1544          40.77            High
# 1 -288.7650         923.63        Critical
#
# [2 rows x 21 columns]

# %%
df.columns


# Here, we have row id, order id and customer id

# So, it means it does not drop the columns from the source or orginal data/table
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# ### To  drop data permanently

# %%
df.drop(columns = ["Row ID","Order ID","Customer ID"], inplace = True)

# %%
df.columns


# Now, we don't have row id, order id and customer id, it means these rows are drop from the source data/table
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'Postal Code', 'City', 'State', 'Country', 'Region', 'Market',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# I want all those rows/index are in loss or not making any profit



df["Profit"] <=0
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: Profit, Length: 51290, dtype: bool

# %%
df[df["Profit"] <=0 ].index
# Out:
# Int64Index([    1,     3,    16,    30,    40,    65,    73,    76,    83,
#                85,
#             ...
#             51252, 51255, 51256, 51257, 51259, 51260, 51266, 51275, 51277,
#             51279],
#            dtype='int64', length=13212)

# %%
# Here, have 13212 rows who is not making any profit. So, drop all these rows



lessthan0= list(df[df["Profit"] <= 0].index)

# %%
# dropping permanently all 13212 rows


df.drop(index = lessthan0, inplace = True)

# %%
df[df["Profit"] <=0 ]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Postal Code, City, State, Country, Region, Market, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]
